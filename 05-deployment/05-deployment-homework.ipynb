# %%
import numpy
import pandas

# %%
# QUESTION 1
# !uv --version
# Out:
# uv 0.9.5 (d5f39331a 2025-10-21)

# %%
# QUESTION 2
# in the command line inside the 05-deployment-homework folder 
# uv add scikit-learn==1.6.1 
# command was executed and the uv.lock file was used to find the hash

# %%
# QUESTION 3
# question3_predict.py file was run inside the virtual environment to find the prob\
# command: uv run python question3_predict.py
# Result: 0.533 (approx)

# %%
# QUESTION 4
# question4_predict.py file was run using uv run python
# while the port was exposed,
# question4_test.py file was run using uv run python to make predictions
# the probability was found in a json as follows 
# {'conversion_probability': 0.5340417283801275, 'convert': True}

# %%
# QUESTION 5
# on inspecting the agrigorev/zoomcamp-model:2025 image from the source
# as well as examining using docker images command (post pulling)
# it is approximately 120702044 bytes = 121 MB (approx)

# %%
# QUESTION 6
# performing the same process but with the addition of port mapping within the docker container
# since the feature set fed was the same 
# but the model was different since the pipeline in the base model was used
# so, for the same prospective cx (as given in the question 4) the probability predicted using the new model(pipeline) 
# changed from 0.534 (approx) to 0.9933 (approx)
